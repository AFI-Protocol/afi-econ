# %% [markdown]
# # Token Minting Sandbox
#
# Interactive experimentation with PoI-based token minting.
#
# TODO: Add actual simulation code and visualizations

# %%
import sys
sys.path.append('..')

from sims.minting import simulate_poi_minting
import matplotlib.pyplot as plt

# TODO: Add simulation and visualization code
