# %% [markdown]
# # Epoch Pulse Emissions Sandbox
#
# Interactive experimentation with Epoch Pulse emissions patterns.
#
# TODO: Add actual simulation code and visualizations

# %%
import sys
sys.path.append('..')

from sims.epoch_pulse import simulate_epoch_pulse
import matplotlib.pyplot as plt

# TODO: Add simulation and visualization code
