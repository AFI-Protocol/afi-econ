# %% [markdown]
# # Validator & Agent Rewards Sandbox
#
# Interactive experimentation with reward distribution and reputation modeling.
#
# TODO: Add actual simulation code and visualizations

# %%
import sys
sys.path.append('..')

from sims.rewards import simulate_validator_rewards
import matplotlib.pyplot as plt

# TODO: Add simulation and visualization code
